# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pathlib
import numpy as np
from PIL import Image

# %%
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
print(gpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data preprocessing

# %%
directory = "C:/Users/USER/Documents/data/catdog"
data_dir = pathlib.Path(directory).with_suffix('')
train_data_dir = data_dir / "training_set"
test_data_dir = data_dir / "test_set"

# %%
image_count = len(list(train_data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 25000

# %%
batch_size = 4
img_height = 128
img_width = 128

# %% [markdown]
# ## Data rotation, zoom

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_ran = ImageDataGenerator(
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    rescale=1./255
)

# %%
train_ds = train_ran.flow_from_directory(train_data_dir,
                                             target_size=(img_width, img_height),
                                             batch_size=batch_size,
                                             class_mode='binary')
# Out:
# Found 25000 images belonging to 2 classes.

# %%
raw_ds = tf.keras.utils.image_dataset_from_directory(
  test_data_dir,
  seed=5,
  image_size=(img_height, img_width))
# Out:
# Found 2023 files belonging to 2 classes.

# %% [markdown]
# ## Normalization

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
val_ds = raw_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
class_names = list(train_ds.class_indices.keys())
print(class_names)
# Out:
# ['cat', 'dog']

# %% [markdown]
# ## Visualization

# %%
image1 = plt.imread(directory + '/training_set/cat/cat.1.jpg')/255
image1 = tf.image.resize(image1, [img_height,img_width])
image2 = plt.imread(directory + '/training_set/dog/dog.1.jpg')/255
image2 = tf.image.resize(image2, [img_height,img_width])
image3 = plt.imread(directory + '/training_set/cat/cat.5.jpg')/255
image3 = tf.image.resize(image3, [img_height,img_width])
image4 = plt.imread(directory + '/training_set/dog/dog.5.jpg')/255
image4 = tf.image.resize(image4, [img_height,img_width])
fig, ax = plt.subplots(2,2, figsize=(5,5))
ax[0,0].imshow(image1)
ax[0,1].imshow(image2)
ax[1,0].imshow(image3)
ax[1,1].imshow(image4)

# %% [markdown]
# # Model

# %%
def mapping(input):
    if np.argmax(input) == 0:
        return "cat"
    else:
        return "dog"

# %% [markdown]
# ## LeNet

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint_filepath = 'best_model2'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True
)
early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
parameters = [
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding="same", input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2, activation='softmax')
]

# %%
tf.debugging.set_log_device_placement(True)
model = tf.keras.Sequential(parameters)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
with tf.device('/device:GPU:0'):
    model.fit(train_ds, epochs=20, validation_data=val_ds, callbacks=[model_checkpoint_callback, early_stopping_callback])
# Out:
# Epoch 1/20
# 391/391 [==============================] - 113s 280ms/step - loss: 0.6274 - accuracy: 0.6487 - val_loss: 0.5429 - val_accuracy: 0.7237
# Epoch 2/20
# 391/391 [==============================] - 100s 256ms/step - loss: 0.5280 - accuracy: 0.7382 - val_loss: 0.4686 - val_accuracy: 0.7677
# Epoch 3/20
# 391/391 [==============================] - 102s 260ms/step - loss: 0.4864 - accuracy: 0.7704 - val_loss: 0.4285 - val_accuracy: 0.8047
# Epoch 4/20
# 391/391 [==============================] - 122s 312ms/step - loss: 0.4638 - accuracy: 0.7864 - val_loss: 0.4019 - val_accuracy: 0.8211
# Epoch 5/20
# 391/391 [==============================] - 124s 317ms/step - loss: 0.4427 - accuracy: 0.7984 - val_loss: 0.4098 - val_accuracy: 0.8171
# Epoch 6/20
# 391/391 [==============================] - 118s 303ms/step - loss: 0.4272 - accuracy: 0.8013 - val_loss: 0.3693 - val_accuracy: 0.8403
# Epoch 7/20
# 391/391 [==============================] - 117s 300ms/step - loss: 0.4162 - accuracy: 0.8135 - val_loss: 0.3635 - val_accuracy: 0.8423
# Epoch 8/20
# 391/391 [==============================] - 118s 303ms/step - loss: 0.4038 - accuracy: 0.8195 - val_loss: 0.3547 - val_accuracy: 0.8423
# Epoch 9/20
# 391/391 [==============================] - 114s 292ms/step - loss: 0.3950 - accuracy: 0.8240 - val_loss: 0.3416 - val_accuracy: 0.8443
# Epoch 10/20
# 391/391 [==============================] - 104s 265ms/step - loss: 0.3800 - accuracy: 0.8302 - val_loss: 0.3751 - val_accuracy: 0.8245
# Epoch 11/20
# 391/391 [==============================] - 99s 252ms/step - loss: 0.3709 - accuracy: 0.8381 - val_loss: 0.3184 - val_accuracy: 0.8596
# Epoch 12/20
# 391/391 [==============================] - 108s 277ms/step - loss: 0.3673 - accuracy: 0.8356 - val_loss: 0.3078 - val_accuracy: 0.8705
# Epoch 13/20
# 391/391 [==============================] - 110s 280ms/step - loss: 0.3625 - accuracy: 0.8422 - val_loss: 0.2934 - val_accuracy: 0.8799
# Epoch 14/20
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3528 - accuracy: 0.8476 - val_loss: 0.2799 - val_accuracy: 0.8735
# Epoch 15/20
# 391/391 [==============================] - 115s 293ms/step - loss: 0.3389 - accuracy: 0.8511 - val_loss: 0.2842 - val_accuracy: 0.8784
# Epoch 16/20
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3359 - accuracy: 0.8523 - val_loss: 0.2701 - val_accuracy: 0.8824
# Epoch 17/20
# 391/391 [==============================] - 100s 256ms/step - loss: 0.3353 - accuracy: 0.8542 - val_loss: 0.2562 - val_accuracy: 0.8893
# Epoch 18/20
# 391/391 [==============================] - 100s 256ms/step - loss: 0.3284 - accuracy: 0.8559 - val_loss: 0.2719 - val_accuracy: 0.8794
# Epoch 19/20
# 391/391 [==============================] - 99s 253ms/step - loss: 0.3225 - accuracy: 0.8613 - val_loss: 0.2428 - val_accuracy: 0.8972
# Epoch 20/20
# 391/391 [==============================] - 104s 265ms/step - loss: 0.3244 - accuracy: 0.8622 - val_loss: 0.2500 - val_accuracy: 0.8888

# %%
results = model.evaluate(val_ds, verbose=0)
print(results)
# Out:
# [0.2499876767396927, 0.8887790441513062]

# %%
model.save("bestModel.h5")

# %%
image1 = plt.imread('cat.jpg')/255
image1 = tf.image.resize(image1, [img_height,img_width])
image1 = tf.image.rot90(image1, k=3)
image2 = plt.imread('cat2.jpeg')/255
image2 = tf.image.resize(image2, [img_height,img_width])
image3 = plt.imread('cat3.jpg')/255
image3 = tf.image.resize(image3, [img_height,img_width])
image4 = plt.imread('dog.jpg')/255
image4 = tf.image.resize(image4, [img_height,img_width])
fig, ax = plt.subplots(2,2, figsize=(5,5))
ax[0,0].imshow(image1)
ax[0,1].imshow(image2)
ax[1,0].imshow(image3)
ax[1,1].imshow(image4)

# %%
mapping(model.predict(image1[tf.newaxis,...]))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 mapping(model.predict(image1[tf.newaxis,...]))
#
# File E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File E:\USER\miniconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/flatten/Reshape' defined at (most recent call last):
#     File "E:\USER\miniconda3\envs\tf\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "E:\USER\miniconda3\envs\tf\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\traitlets\config\application.py", line 1053, in launch_instance
#       app.start()
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\kernelapp.py", line 737, in start
#       self.io_loop.start()
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "E:\USER\miniconda3\envs\tf\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "E:\USER\miniconda3\envs\tf\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "E:\USER\miniconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 524, in dispatch_queue
#       await self.process_one()
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 513, in process_one
#       await dispatch(*args)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 418, in dispatch_shell
#       await result
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 758, in execute_request
#       reply_content = await reply_content
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\ipkernel.py", line 426, in do_execute
#       res = shell.run_cell(
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3046, in run_cell
#       result = self._run_cell(
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3101, in _run_cell
#       result = runner(coro)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3306, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3488, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3548, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\USER\AppData\Local\Temp\ipykernel_18088\3888718293.py", line 1, in <module>
#       mapping(model.predict(image1[tf.newaxis,...]))
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "E:\USER\miniconda3\envs\tf\lib\site-packages\keras\layers\reshaping\flatten.py", line 104, in call
#       return tf.reshape(inputs, flattened_shape)
# Node: 'sequential/flatten/Reshape'
# Input to reshape is a tensor with 100352 values, but the requested shape requires a multiple of 32768
# 	 [[{{node sequential/flatten/Reshape}}]] [Op:__inference_predict_function_40976]

# %%
mapping(model.predict(image2[tf.newaxis,...]))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 'dog'

# %%
mapping(model.predict(image3[tf.newaxis,...]))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 'cat'

# %%
mapping(model.predict(image4[tf.newaxis,...]))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 'cat'

# %%
image_batch, labels_batch = next(iter(val_ds))

# %%
from sklearn.metrics import confusion_matrix, classification_report
predictions = np.argmax(model.predict(image_batch), axis=1)
cm = confusion_matrix(labels_batch, predictions)
clr = classification_report(labels_batch, predictions, zero_division=0)
print(clr)
# Out:
# 1/1 [==============================] - 0s 25ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %%
import seaborn as sns
plt.figure(figsize=(30, 30))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !nvidia-smi
# Out:
# Thu Nov 16 21:49:19 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.01                 Driver Version: 546.01       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3050      WDDM  | 00000000:01:00.0  On |                  N/A |
# | 30%   42C    P8               7W / 130W |    941MiB /  8192MiB |      7%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      5628    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      8784    C+G   ...inaries\Win64\EpicGamesLauncher.exe    N/A      |
# |    0   N/A  N/A      9544    C+G   ...al\Discord\app-1.0.9024\Discord.exe    N/A      |
# |    0   N/A  N/A      9644    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10872    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe    N/A      |
# |    0   N/A  N/A     11052    C+G   ...1.0_x64__8wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A     11768    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     11952    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     12420    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     12960    C+G   ...B\system_tray\lghub_system_tray.exe    N/A      |
# |    0   N/A  N/A     13040    C+G   C:\Program Files\LGHUB\lghub.exe          N/A      |
# |    0   N/A  N/A     13520    C+G   ...81.0_x64__8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A     14756    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     14800    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     18828    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     20364      C   E:\USER\miniconda3\envs\tf\python.exe     N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## AlexNet

# %%
parameters = [
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11, 11), activation='relu', padding="same", input_shape=(img_width, img_height, 3)),
    tf.keras.layers.MaxPooling2D((3, 3), strides=2),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5, 5), padding="same", activation='relu'),
    tf.keras.layers.MaxPooling2D((3, 3), strides=2),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3, 3), padding="same", activation='relu'),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3, 3), padding="same", activation='relu'),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation='relu'),
    tf.keras.layers.MaxPooling2D((3, 3), strides=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2, activation='softmax')
]

# %%
with tf.device('/CPU:0'):
    alexNet = tf.keras.Sequential(parameters)
    alexNet.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
with tf.device('/GPU:0'):
    alexNet.fit(train_ds, epochs=20, validation_data=val_ds, batch_size=8, callbacks=[model_checkpoint_callback, early_stopping_callback])
# Out:
# Epoch 1/20
#  384/6250 [>.............................] - ETA: 2:01:14 - loss: 0.6941 - accuracy: 0.5117
# KeyboardInterrupt
