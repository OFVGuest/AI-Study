# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Data obtaining

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Mapping the outputs

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Data visualization

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# Scaling values from 0 to 1. The scaling is important as we know so it is easier to the model to process and fit.

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# We can print the first 25 images to show our training dataset and the outputs

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # Posprocessing

# %% [markdown]
# ## Model building

# %% [markdown]
# The most important and basic concept of neural networks are the layers. Layers extract representations from the data and gives us the information we want to. In order to do so we must help them with weights and biases.
# Dense in tensorflow is a layer, hidden, sequential, output or whatever

# %% [markdown]
# The flatten function transforms the $R^n$ matrix into a $R^1$ vector. And thats it. Only transform.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# Following the documentation from TensorFlow, there are important steps before fitting the model.\
# Before the model is ready for training, it needs a few more settings. These are added during the model's compile step:\
# **Optimizer** : This is how the model is updated based on the data it sees and its loss function.\
# **Loss function** : This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.\
# **Metrics** : Used to monitor the training and testing steps. The following example uses accuracy, the fraction of the images that are correctly classified.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 3ms/step - loss: 1.0813 - accuracy: 0.6697
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6390 - accuracy: 0.7686
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5624 - accuracy: 0.7995
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5193 - accuracy: 0.8173
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4917 - accuracy: 0.8268
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4727 - accuracy: 0.8336
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4582 - accuracy: 0.8380
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4468 - accuracy: 0.8432
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4369 - accuracy: 0.8460
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.4576 - accuracy: 0.8345 - 1s/epoch - 4ms/step
#
# Test accuracy: 0.8345000147819519

# %% [markdown]
# ## Predictions

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
